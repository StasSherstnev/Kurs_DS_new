# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.datasets import load_diabetes
from sklearn.linear_model import LinearRegression,Ridge
from sklearn.metrics import mean_squared_error, r2_score

# %%
X, y = load_diabetes(return_X_y=True)

# Use only one feature
X = X[:, np.newaxis, 2]

X_train = X[:-45]
X_test = X[-45:]

y_train = y[:-45]
y_test = y[-45:]
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((397, 1), (45, 1), (397,), (45,))

# %%
# %%time
lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# CPU times: total: 0 ns
# Wall time: 19.5 ms
# LinearRegression()

# %%
y_pred = lr.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("Coefficients:\n", lr.coef_)
print(f"MSE: {mse:.2f}")
print(f"R2: {r2:.2f}")
# Out:
# Coefficients:
#  [953.02484976]
# MSE: 3203.71
# R2: 0.42

# %%
plt.scatter(X_test, y_test, color="black")
plt.plot(X_test, y_pred, color="blue", linewidth=3)

plt.xticks(())
plt.yticks(())

plt.show()

# %%
X, y = load_diabetes(return_X_y=True)

X_train = X[:-45]
X_test = X[-45:]

y_train = y[:-45]
y_test = y[-45:]
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((397, 10), (45, 10), (397,), (45,))

# %%
# %%time
lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# CPU times: total: 0 ns
# Wall time: 8.29 ms
# LinearRegression()

# %%
y_pred = lr.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("Coefficients:\n", lr.coef_)
print(f"MSE: {mse:.2f}")
print(f"R2: {r2:.2f}")
# Out:
# Coefficients:
#  [-4.32267019e-01 -2.37522416e+02  5.20210764e+02  3.04171914e+02
#  -7.51563208e+02  4.29790050e+02  9.94674947e+01  2.14872395e+02
#   6.89370808e+02  9.73256066e+01]
# MSE: 1735.89
# R2: 0.69

# %%
from sklearn.model_selection import train_test_split

# %%
X, y = load_diabetes(return_X_y=True)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((397, 10), (45, 10), (397,), (45,))

# %%
# %%time
lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# CPU times: total: 0 ns
# Wall time: 1.99 ms
# LinearRegression()

# %%
y_pred = lr.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("Coefficients:\n", lr.coef_)
print(f"MSE: {mse:.2f}")
print(f"R2: {r2:.2f}")
# Out:
# Coefficients:
#  [  19.92730105 -262.5526422   509.19584695  336.09319329 -849.30479304
#   480.22664735  120.69064852  236.72228404  716.61278802   70.41001991]
# MSE: 2743.91
# R2: 0.55

# %%
X, y = load_diabetes(return_X_y=True)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, shuffle = False, random_state=42)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((397, 10), (45, 10), (397,), (45,))

# %%
# %%time
lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# CPU times: total: 0 ns
# Wall time: 2 ms
# LinearRegression()

# %%
y_pred = lr.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("Coefficients:\n", lr.coef_)
print(f"MSE: {mse:.2f}")
print(f"R2: {r2:.2f}")
# Out:
# Coefficients:
#  [-4.32267019e-01 -2.37522416e+02  5.20210764e+02  3.04171914e+02
#  -7.51563208e+02  4.29790050e+02  9.94674947e+01  2.14872395e+02
#   6.89370808e+02  9.73256066e+01]
# MSE: 1735.89
# R2: 0.69

# %%
from sklearn.model_selection import cross_val_score

# %%
# %%time
X, y = load_diabetes(return_X_y=True)
lr = LinearRegression()
scores = cross_val_score(lr, X, y, cv=5)
scores.mean(), scores.std()
# Out:
# CPU times: total: 0 ns
# Wall time: 13.7 ms
# (0.48231643590864215, 0.04926857751190378)

# %%
# %%time
X, y = load_diabetes(return_X_y=True)
lr = LinearRegression()
scores = cross_val_score(lr, X, y, cv=5, scoring='r2_score')
scores.mean(), scores.std()
# Out:
# ---------------------------------------------------------------------------
# InvalidParameterError                     Traceback (most recent call last)
# File <timed exec>:3
#
# File c:\Users\Stas\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py:203, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     200 to_ignore += ["self", "cls"]
#     201 params = {k: v for k, v in params.arguments.items() if k not in to_ignore}
# --> 203 validate_parameter_constraints(
#     204     parameter_constraints, params, caller_name=func.__qualname__
#     205 )
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
#
# File c:\Users\Stas\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py:95, in validate_parameter_constraints(parameter_constraints, params, caller_name)
#      89 else:
#      90     constraints_str = (
#      91         f"{', '.join([str(c) for c in constraints[:-1]])} or"
#      92         f" {constraints[-1]}"
#      93     )
# ---> 95 raise InvalidParameterError(
#      96     f"The {param_name!r} parameter of {caller_name} must be"
#      97     f" {constraints_str}. Got {param_val!r} instead."
#      98 )
#
# InvalidParameterError: The 'scoring' parameter of cross_val_score must be a str among {'balanced_accuracy', 'positive_likelihood_ratio', 'max_error', 'f1_weighted', 'matthews_corrcoef', 'recall_micro', 'homogeneity_score', 'precision', 'roc_auc_ovr', 'neg_root_mean_squared_log_error', 'completeness_score', 'precision_macro', 'roc_auc_ovo_weighted', 'recall_samples', 'neg_brier_score', 'neg_negative_likelihood_ratio', 'mutual_info_score', 'neg_mean_absolute_percentage_error', 'explained_variance', 'precision_weighted', 'jaccard_samples', 'normalized_mutual_info_score', 'neg_mean_squared_error', 'neg_median_absolute_error', 'fowlkes_mallows_score', 'neg_root_mean_squared_error', 'roc_auc_ovo', 'adjusted_mutual_info_score', 'f1_samples', 'neg_mean_absolute_error', 'v_measure_score', 'jaccard', 'average_precision', 'f1', 'adjusted_rand_score', 'recall_weighted', 'recall', 'roc_auc', 'neg_log_loss', 'jaccard_macro', 'top_k_accuracy', 'jaccard_weighted', 'accuracy', 'precision_samples', 'precision_micro', 'neg_mean_squared_log_error', 'rand_score', 'f1_macro', 'jaccard_micro', 'f1_micro', 'r2', 'recall_macro', 'neg_mean_gamma_deviance', 'roc_auc_ovr_weighted', 'neg_mean_poisson_deviance'}, a callable or None. Got 'r2_score' instead.

# %%
import sklearn
sorted(sklearn.metrics.SCORERS.keys())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[21], line 2
#       1 import sklearn
# ----> 2 sorted(sklearn.metrics.SCORERS.keys())
#
# AttributeError: module 'sklearn.metrics' has no attribute 'SCORERS'

# %%
# %%time
X, y = load_diabetes(return_X_y=True)
lr = LinearRegression()
scores = cross_val_score(lr, X, y, cv=5, scoring='r2')
scores.mean(), scores.std()
# Out:
# CPU times: total: 15.6 ms
# Wall time: 13.3 ms
# (0.48231643590864215, 0.04926857751190378)

# %%
np.random.seed(42)

n_samples, n_features = 10**4, 500
X = np.random.randn(n_samples, n_features)
true_coef = 3 * np.random.randn(n_features)

y = np.dot(X, true_coef)

# %%
# %%time
lr = LinearRegression()
lr.fit(X,y)
print (f'R2: {lr.score(X,y):.4f}')
# Out:
# R2: 1.0000
# CPU times: total: 766 ms
# Wall time: 327 ms

# %%
# %%time
ridge = Ridge(alpha=0.0, solver='sparse_cg')
ridge.fit(X,y)
print (f'R2: {ridge.score(X,y):.4f}')
# Out:
# R2: 1.0000
# CPU times: total: 156 ms
# Wall time: 82 ms

# %%
np.random.seed(42)

n_samples, n_features = 10**4, 500
X = np.random.randn(n_samples, n_features)
true_coef = 3 * np.random.randn(n_features)

y = np.dot(X, true_coef)

# Add some noise
y += 25 * np.random.normal(size=(n_samples,))

# %%
# %%time
lr = LinearRegression()
lr.fit(X,y)
print (f'R2: {lr.score(X,y):.4f}')
# Out:
# R2: 0.8878
# CPU times: total: 750 ms
# Wall time: 304 ms

# %%
# %%time
ridge = Ridge(alpha=0.0, solver='sparse_cg')
ridge.fit(X,y)
print (f'R2: {ridge.score(X,y):.4f}')
# Out:
# R2: 0.8878
# CPU times: total: 234 ms
# Wall time: 83.7 ms

# %% [markdown]
# https://scikit-learn.org/stable/user_guide.html
#
# https://scikit-learn.org/stable/modules/classes.html
#
# https://scikit-learn.org/stable/auto_examples/index.html
#
#
# https://scikit-learn.org/stable/modules/linear_model.html
#
# https://scikit-learn.org/stable/modules/sgd.html
#
# https://scikit-learn.org/stable/modules/cross_validation.html
